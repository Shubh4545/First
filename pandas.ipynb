# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubh4545/First/blob/master/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pandas**

# %%
import numpy as np
s = np.array(['a','b'])
print(type(s))

arry = np.array([[1,2,3],[1,2,3]])
print(arry)
# Out:
# <class 'numpy.ndarray'>
# [[1 2 3]
#  [1 2 3]]

# %%
import pandas as pd
import numpy as np
#s = np.array(['a','b'])
data = pd.Series((1,2,3,4,5),index=[1,2,3,4,9]) 
print(data[[1,4,9]])
# Out:
# 1    1
# 4    4
# 9    5
# dtype: int64

# %% [markdown]
# List and arry to series

# %%
dictdata = {'a':1,'b':2}
s=pd.Series(dictdata)
s
# Out:
# a    1
# b    2
# dtype: int64

# %% [markdown]
# Dict to series

# %% [markdown]
# # Dataframe

# %%
import pandas as pd
data =[1,2,3,4,5]
df = pd.DataFrame(data)
print(df)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
import pandas as pd
data = [['guvi1',10,'samsaur'],['guvi2',12,'pune'],['guvi3',15,'latur']]
df = pd.DataFrame(data,columns=['Name','Age','place'],dtype=str)
print(df)
print(type(df))
# Out:
#     Name Age    place
# 0  guvi1  10  samsaur
# 1  guvi2  12     pune
# 2  guvi3  15    latur
# <class 'pandas.core.frame.DataFrame'>

# %%
import pandas as pd
data = {'Name':['shubham','ajay'],'Age':[10,2]}
df=pd.DataFrame(data)
print(df)
# Out:
#       Name  Age
# 0  shubham   10
# 1     ajay    2

# %%
import pandas as pd
data= {
    'Year':[10,11,12,11,12,12,11],
    'Team':['CSK','MI','DD','SRH','KKR','BEN','PUN'],
    'Wins':[11,11,1,2,11,3,12],
    'losses':[2,4,1,4,1,3,1]
}
ipl = pd.DataFrame(data)
ipl
# Out:
#    Year Team  Wins  losses
# 0    10  CSK    11       2
# 1    11   MI    11       4
# 2    12   DD     1       1
# 3    11  SRH     2       4
# 4    12  KKR    11       1
# 5    12  BEN     3       3
# 6    11  PUN    12       1

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
ipl.hist(bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2ceaae4450>,
# ...
#       dtype=object)

# %%
print(ipl.dtypes)#find coloumn datatype
ipl.describe()#IQR inter quartile range 25%,50%
# Out:
# Year       int64
# Team      object
# Wins       int64
# losses     int64
# dtype: object
#             Year       Wins    losses
# count   7.000000   7.000000  7.000000
# mean   11.285714   7.285714  2.285714
# std     0.755929   4.990467  1.380131
# min    10.000000   1.000000  1.000000
# 25%    11.000000   2.500000  1.000000
# 50%    11.000000  11.000000  2.000000
# 75%    12.000000  11.000000  3.500000
# max    12.000000  12.000000  4.000000

# %%
ipl.info()#check null values present in column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    7 non-null      int64
#  1   Team    7 non-null      object
#  2   Wins    7 non-null      int64
#  3   losses  7 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 352.0+ bytes

# %%
ipl.boxplot()#box plot
ipl.plot()#linear lines

# %%
ipl.plot.line(y="Wins")
ipl.plot.pie(y="Wins")

# %%
#ipl.head(5)
ipl.tail(5)
# Out:
#    Year Team  Wins  losses
# 2    12   DD     1       1
# 3    11  SRH     2       4
# 4    12  KKR    11       1
# 5    12  BEN     3       3
# 6    11  PUN    12       1

# %% [markdown]
# Ascending values

# %%
print(ipl.sort_values(by=["losses"],ascending=True))
# Out:
#    Year Team  Wins  losses
# 2    12   DD     1       1
# 4    12  KKR    11       1
# 6    11  PUN    12       1
# 0    10  CSK    11       2
# 5    12  BEN     3       3
# 1    11   MI    11       4
# 3    11  SRH     2       4

# %%
print(ipl.mul(2)["Wins"])
# Out:
# 0    22
# 1    22
# 2     2
# 3     4
# 4    22
# 5     6
# 6    24
# Name: Wins, dtype: int64

# %%
ipl.to_csv("ipl.csv")
ipl.to_csv("ipl.json")
ipl.to_csv("ipl.hrtml")

# %%
print(ipl.columns[2])
print(ipl["Year"])
# Out:
# Wins
# 0    10
# 1    11
# 2    12
# 3    11
# 4    12
# 5    12
# 6    11
# Name: Year, dtype: int64

# %%
print(ipl.iloc[[0,1,2]])
#print(ipl.iloc[0:2])
# Out:
#    Year Team  Wins  losses
# 0    10  CSK    11       2
# 1    11   MI    11       4
# 2    12   DD     1       1

# %%
print(ipl.iloc[:,[0,3]])
# Out:
#    Year  losses  Wins
# 0    10       2    11
# 1    11       4    11
# 2    12       1     1
# 3    11       4     2
# 4    12       1    11
# 5    12       3     3
# 6    11       1    12

# %%
print(ipl.iloc[:,0:2])
# Out:
#    Year Team
# 0    10  CSK
# 1    11   MI
# 2    12   DD
# 3    11  SRH
# 4    12  KKR
# 5    12  BEN
# 6    11  PUN

# %%
ipl.iloc[1:3,1:3]
# Out:
#   Team  Wins
# 1   MI    11
# 2   DD     1

# %%
print(ipl.drop(columns='losses',inplace=True))#DROP COLUMNS
# Out:
# None

# %%
ipl
# Out:
#    Year Team  Wins
# 0    10  CSK    11
# 1    11   MI    11
# 2    12   DD     1
# 3    11  SRH     2
# 4    12  KKR    11
# 5    12  BEN     3
# 6    11  PUN    12

# %%
ipl.drop(index=0)#drop rows
# Out:
#    Year Team  Wins
# 1    11   MI    11
# 2    12   DD     1
# 3    11  SRH     2
# 4    12  KKR    11
# 5    12  BEN     3
# 6    11  PUN    12

# %%
ipl["Team"].unique()

# %%
ipl["Team"].unique()
# Out:
# array(['CSK', 'MI', 'DD', 'SRH', 'KKR', 'BEN', 'PUN'], dtype=object)

# %% [markdown]
# #Data importing

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/nethajinirmal13/Training-datasets/main/diabetes.csv')
df
#print(df.to_string())
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
print(df.plot('Pregnancies','Age'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
shape = df.shape
print(shape)
# Out:
# (768, 9)

# %%
size = df.size
print(size)
# Out:
# 6912

# %%
df.plot(0,7)

# %%
df['Pregnancies'].hist(bins=20)

# %%
df.isnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# ...

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/nethajinirmal13/Training-datasets/main/titanic_train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
# Out:
# (891, 12)

# %%
df.shape
de=df.dropna()
de.shape
# Out:
# (183, 12)

# %%
de.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.drop("Cabin",axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-79-3201f8cd8f71> in <module>()
# ----> 1 df.drop("Cabin",axis=1,inplace=True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["Age"].fillna(method='ffill',inplace=True)#bfill,backfill,ffill

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
df["Age"].fillna(2)#fill your value

# %%
import pandas as pd

data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409.1,
    "1":479.0,
    "2":340.0,
    "3":282.4,
    "4":406.0,
    "5":300.5
  }
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.5

# %%
import pandas as pd
df=pd.read_csv('dirtydata.csv')
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
df.shape
#df.size
# Out:
# (32, 5)

# %%
new_df = df.dropna()
print(new_df.to_string())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-8fff64e03857> in <module>()
#       1 new_df = df.dropna(inplace=True)
# ----> 2 print(new_df.to_string())
#
# AttributeError: 'NoneType' object has no attribute 'to_string'

# %%
new_df.shape
# Out:
# (29, 5)

# %%
import pandas as pd

df = pd.read_csv('/content/titanic_train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import pandas as pd
data1 = {
    'ID': ['1','2','3','4'],
    'Feature1':['A','B','C','D'],
    'Feature2':['L','M','N','O']

}

# %%
df1 = pd.DataFrame(data1,columns=["ID","Feature1","Feature2"])

# %%
df1
# Out:
#   ID Feature1 Feature2
# 0  1        A        L
# 1  2        B        M
# 2  3        C        N
# 3  4        D        O

# %%
data2 = {
    'ID': ['1','5','6','7'],
    'Feature1':['Ab','Bc','Cd','De'],
    'Feature2':['Lm','Mn','No','Op']

}

# %%
#df2 = pd.DataFrame(data2,columns=["ID","Feature1","Feature2"])
df2 = pd.DataFrame(data2,columns=["ID","Feature1","Feature2"])

# %%
df2
# Out:
#   ID Feature1 Feature2
# 0  1       Ab       Lm
# 1  5       Bc       Mn
# 2  6       Cd       No
# 3  7       De       Op

# %%
df = pd.concat([df1,df2],ignore_index=True)#To get indexing properl

# %%
dff = pd.concat([df1,df2],keys=["1st","2nd"])

# %%
dff
# Out:
#       ID Feature1 Feature2
# 1st 0  1        A        L
#     1  2        B        M
#     2  3        C        N
#     3  4        D        O
# 2nd 0  1       Ab       Lm
#     1  5       Bc       Mn
#     2  6       Cd       No
#     3  7       De       Op

# %%
dff = pd.concat([df1,df2],sort=True)

# %%
dff
# Out:
#   Feature1 Feature2 ID
# 0        A        L  1
# 1        B        M  2
# 2        C        N  3
# 3        D        O  4
# 0       Ab       Lm  1
# 1       Bc       Mn  5
# 2       Cd       No  6
# 3       De       Op  7

# %%
df_merge_i=pd.merge(df1,df2,on = "ID",how = 'inner')
df_merge_r=pd.merge(df1,df2,on = "ID",how = 'right')
df_merge_l=pd.merge(df1,df2,on = "ID",how = 'left')
df_merge_o=pd.merge(df1,df2,on = "ID",how = 'outer')

# %%
#df_merge_o
df_merge_r
#df_merge_l
#df_merge_o
# Out:
#   ID Feature1_x Feature2_x Feature1_y Feature2_y
# 0  1          A          L         Ab         Lm
# 1  5        NaN        NaN         Bc         Mn
# 2  6        NaN        NaN         Cd         No
# 3  7        NaN        NaN         De         Op

# %%
cross = pd.merge(df1,df2,how = 'cross')

# %%
cross
# Out:
#    ID_x Feature1_x Feature2_x ID_y Feature1_y Feature2_y
# 0     1          A          L    1         Ab         Lm
# 1     1          A          L    5         Bc         Mn
# 2     1          A          L    6         Cd         No
# 3     1          A          L    7         De         Op
# 4     2          B          M    1         Ab         Lm
# 5     2          B          M    5         Bc         Mn
# 6     2          B          M    6         Cd         No
# 7     2          B          M    7         De         Op
# 8     3          C          N    1         Ab         Lm
# 9     3          C          N    5         Bc         Mn
# 10    3          C          N    6         Cd         No
# 11    3          C          N    7         De         Op
# 12    4          D          O    1         Ab         Lm
# 13    4          D          O    5         Bc         Mn
# 14    4          D          O    6         Cd         No
# ...

# %%
#d = df1.join(df3) it requrire diff column name t will increasetable horizentally

# %%
#melt

# %%
import pandas as pd
titanic = pd.read_csv('/content/titanic_train.csv')

# %%
titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.shape
# Out:
# (891, 12)

# %%
df_group_sex = titanic.groupby('Age')

# %%
df_group_sex.ngroups#total number of groups
# Out:
# 88

# %%
df_group_sex.apply(display)
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander  male
#
#       Age  SibSp  Parch Ticket    Fare Cabin Embarked
# 803  0.42      0      1   2625  8.5167   NaN        C
#      PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 755          756         1       2  Hamalainen, Master. Viljo  male  0.67
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 755      1      1  250649  14.5   NaN        S
#      PassengerId  Survived  Pclass                           Name     Sex  \
# 469          470         1       3  Baclini, Miss. Helene Barbara  female
# 644          645         1       3         Baclini, Miss. Eugenie  female
#
#       Age  SibSp  Parch Ticket     Fare Cabin Embarked
# 469  0.75      2      1   2666  19.2583   NaN        C
# 644  0.75      2      1   2666  19.2583   NaN        C
# ...

# %%
df_group_sex.apply(print)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.groupby('Sex').Age.agg(['max','min','count'])
# Out:
#          max   min  count
# Sex
# female  63.0  0.75    261
# male    80.0  0.42    453

# %%
a=pd.DataFrame(titanic["Fare"]==0)
a.groupby("Fare").size()
# Out:
# Fare
# False    876
# True      15
# dtype: int64

# %%
i=0
if(a[i]==True):
  print(a[i])
  i+=1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
pd.pivot_table(titanic,index = ['Pclass'])
# Out:
#               count                                                            \
#                 Age Cabin Embarked Fare Name Parch PassengerId SibSp Survived
# Sex    Pclass
# female 1         85    81       92   94   94    94          94    94       94
#        2         74    10       76   76   76    76          76    76       76
#        3        102     6      144  144  144   144         144   144      144
# male   1        101    95      122  122  122   122         122   122      122
#        2         99     6      108  108  108   108         108   108      108
#        3        253     6      347  347  347   347         347   347      347
#
#
#               Ticket
# Sex    Pclass
# female 1          94
#        2          76
#        3         144
# male   1         122
#        2         108
#        3         347
